# %%
print("hey Richa Sharma...")
# Out:
# hey Richa Sharma...

# %%
20+8
# Out:
# 28

# %% [markdown]
# This is markdown cell for notes

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[8]
# Out:
# 'r'

# %% [markdown]
# Python trick to reverse a string

# %%
mystring[::-1]
# Out:
# 'dlroW olleH'
